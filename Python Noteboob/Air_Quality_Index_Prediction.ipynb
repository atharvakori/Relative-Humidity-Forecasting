# %%
import numpy as np;
import pandas as pd;

# %%
airQualityData = pd.read_csv('/content/AirQualityUCI.csv', sep=';', decimal=',');

# %%
airQualityData.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
 airQualityData.drop(columns=['Unnamed: 15', 'Unnamed: 16'], inplace=True);


# Below are other syntax to drop last two rows

#   airQualityData.drop(['Unnamed: 15', 'Unnamed: 16'], axis=1, inplace=True);
#   airQualityData = airQualityData.iloc[::-2]

# %%
airQualityData.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
airQualityData.tail()
# Out:
#      Date Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 9466  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9467  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9468  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9469  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9470  NaN  NaN     NaN          NaN       NaN       NaN            NaN
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH  AH
# 9466      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9467      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9468      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9469      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9470      NaN           NaN      NaN           NaN          NaN NaN NaN NaN

# %%
airQualityData.shape
# Out:
# (9471, 15)

# %%
airQualityData = airQualityData.loc[:9356]
# airQualityData = airQualityData.drop(airQualityData.index[9356], axis = 0)
# airQualityData.drop(airQualityData.index[9356], axis = 0, inplace = True)
# airQualityData = airQualityData.iLoc[:9356]
# airQualityData = airQualityData.head(9357)

# %%
airQualityData
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
airQualityData.shape
# Out:
# (9357, 15)

# %%
airQualityData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
# To check no. of null value
airQualityData.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# Above output shows that there is isn't any missing value, but in the description of dataset(while downloading) missing are there and they are labled or numberd as '-200'. As you can see the last few line when we print the Datafram

# %%
airQualityData.replace(to_replace=-200.0, value=np.nan, inplace=True)
# Out:
# <ipython-input-182-def2afba3164>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
airQualityData.isnull().sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
# Handing missing values

# %%
# Replacing the missing value with mean values of each col. (This is only for project, in the real realproject missing values are handled different way)
# airQualityData.fillna(airQualityData.mean(), inplace=True)

# %%
airQualityData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         7674 non-null   float64
#  3   PT08.S1(CO)    8991 non-null   float64
#  4   NMHC(GT)       914 non-null    float64
#  5   C6H6(GT)       8991 non-null   float64
#  6   PT08.S2(NMHC)  8991 non-null   float64
#  7   NOx(GT)        7718 non-null   float64
#  8   PT08.S3(NOx)   8991 non-null   float64
#  9   NO2(GT)        7715 non-null   float64
#  10  PT08.S4(NO2)   8991 non-null   float64
#  11  PT08.S5(O3)    8991 non-null   float64
#  12  T              8991 non-null   float64
#  13  RH             8991 non-null   float64
#  14  AH             8991 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
airQualityData.mean(numeric_only=True)
# Out:
# CO(GT)              2.152750
# PT08.S1(CO)      1099.833166
# NMHC(GT)          218.811816
# C6H6(GT)           10.083105
# PT08.S2(NMHC)     939.153376
# NOx(GT)           246.896735
# PT08.S3(NOx)      835.493605
# NO2(GT)           113.091251
# PT08.S4(NO2)     1456.264598
# PT08.S5(O3)      1022.906128
# T                  18.317829
# RH                 49.234201
# AH                  1.025530
# dtype: float64

# %%
airQualityData.replace(to_replace=np.nan, value=airQualityData.mean(numeric_only=True), inplace=True)
# Out:
# <ipython-input-188-40882850ea66>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
airQualityData.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)    NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0  218.811816      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0  218.811816      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0  218.811816      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0  218.811816       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0  218.811816      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# ...

# %%
airQualityData.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
# Converting DD-MM-YYYY to YYYY-MM-DD

dateInfo = pd.to_datetime(airQualityData['Date'], format="%d/%m/%Y")
dateInfo
# Out:
# 0      2004-03-10
# 1      2004-03-10
# 2      2004-03-10
# 3      2004-03-10
# 4      2004-03-10
#           ...
# 9352   2005-04-04
# 9353   2005-04-04
# 9354   2005-04-04
# 9355   2005-04-04
# 9356   2005-04-04
# Name: Date, Length: 9357, dtype: datetime64[ns]

# %%
time_info = airQualityData['Time'].apply(lambda x: x.replace('.',':'))
time_info
# Out:
# 0       18:00:00
# 1       19:00:00
# 2       20:00:00
# 3       21:00:00
# 4       22:00:00
#           ...
# 9352    10:00:00
# 9353    11:00:00
# 9354    12:00:00
# 9355    13:00:00
# 9356    14:00:00
# Name: Time, Length: 9357, dtype: object

# %%
date_time = pd.concat([dateInfo,time_info],axis=1)

# %%
date_time
# Out:
#            Date      Time
# 0    2004-03-10  18:00:00
# 1    2004-03-10  19:00:00
# 2    2004-03-10  20:00:00
# 3    2004-03-10  21:00:00
# 4    2004-03-10  22:00:00
# ...         ...       ...
# 9352 2005-04-04  10:00:00
# 9353 2005-04-04  11:00:00
# 9354 2005-04-04  12:00:00
# 9355 2005-04-04  13:00:00
# 9356 2005-04-04  14:00:00
#
# [9357 rows x 2 columns]

# %%
type(date_time)
# Out:
# pandas.core.frame.DataFrame

# %%
date_time['ds'] = date_time['Date'].astype(str) + ' ' + date_time['Time'].astype(str)

# %%
date_time
# Out:
#            Date      Time                   ds
# 0    2004-03-10  18:00:00  2004-03-10 18:00:00
# 1    2004-03-10  19:00:00  2004-03-10 19:00:00
# 2    2004-03-10  20:00:00  2004-03-10 20:00:00
# 3    2004-03-10  21:00:00  2004-03-10 21:00:00
# 4    2004-03-10  22:00:00  2004-03-10 22:00:00
# ...         ...       ...                  ...
# 9352 2005-04-04  10:00:00  2005-04-04 10:00:00
# 9353 2005-04-04  11:00:00  2005-04-04 11:00:00
# 9354 2005-04-04  12:00:00  2005-04-04 12:00:00
# 9355 2005-04-04  13:00:00  2005-04-04 13:00:00
# 9356 2005-04-04  14:00:00  2005-04-04 14:00:00
#
# [9357 rows x 3 columns]

# %%
date_time['ds'] = pd.to_datetime(date_time['ds'])

# %%
type(date_time['ds'])
# Out:
# pandas.core.series.Series

# %%
date_time['ds'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9357 entries, 0 to 9356
# Series name: ds
# Non-Null Count  Dtype
# --------------  -----
# 9357 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 73.2 KB

# %%
date_time.drop(columns=['Date', 'Time'], inplace=True)

# %%
date_time
# Out:
#                       ds
# 0    2004-03-10 18:00:00
# 1    2004-03-10 19:00:00
# 2    2004-03-10 20:00:00
# 3    2004-03-10 21:00:00
# 4    2004-03-10 22:00:00
# ...                  ...
# 9352 2005-04-04 10:00:00
# 9353 2005-04-04 11:00:00
# 9354 2005-04-04 12:00:00
# 9355 2005-04-04 13:00:00
# 9356 2005-04-04 14:00:00
#
# [9357 rows x 1 columns]

# %%
data = pd.DataFrame(date_time['ds'])

# %%
data['y'] = airQualityData['RH']

# %%
data
# Out:
#                       ds     y
# 0    2004-03-10 18:00:00  48.9
# 1    2004-03-10 19:00:00  47.7
# 2    2004-03-10 20:00:00  54.0
# 3    2004-03-10 21:00:00  60.0
# 4    2004-03-10 22:00:00  59.6
# ...                  ...   ...
# 9352 2005-04-04 10:00:00  29.3
# 9353 2005-04-04 11:00:00  23.7
# 9354 2005-04-04 12:00:00  18.3
# 9355 2005-04-04 13:00:00  13.5
# 9356 2005-04-04 14:00:00  13.1
#
# [9357 rows x 2 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
from prophet import Prophet

# %%
model = Prophet()

# %%
model.fit(data)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp_pwm7ugd/6f6st0jp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp_pwm7ugd/_plzm59b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1864', 'data', 'file=/tmp/tmp_pwm7ugd/6f6st0jp.json', 'init=/tmp/tmp_pwm7ugd/_plzm59b.json', 'output', 'file=/tmp/tmp_pwm7ugd/prophet_modelclalv1cu/prophet_model-20250404113427.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:34:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:34:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prediction = model.make_future_dataframe(periods=365, freq='H')
# Out:
# /usr/local/lib/python3.11/dist-packages/prophet/forecaster.py:1854: FutureWarning:
#
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.

# %%
prediction
# Out:
#                       ds
# 0    2004-03-10 18:00:00
# 1    2004-03-10 19:00:00
# 2    2004-03-10 20:00:00
# 3    2004-03-10 21:00:00
# 4    2004-03-10 22:00:00
# ...                  ...
# 9717 2005-04-19 15:00:00
# 9718 2005-04-19 16:00:00
# 9719 2005-04-19 17:00:00
# 9720 2005-04-19 18:00:00
# 9721 2005-04-19 19:00:00
#
# [9722 rows x 1 columns]

# %%
forcast = model.predict(prediction)

# %%
forcast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#                       ds       yhat  yhat_lower  yhat_upper
# 9717 2005-04-19 15:00:00  33.494204   17.898159   48.645177
# 9718 2005-04-19 16:00:00  33.977616   18.502560   49.479999
# 9719 2005-04-19 17:00:00  35.610862   20.141078   51.440966
# 9720 2005-04-19 18:00:00  38.506470   23.367443   54.022510
# 9721 2005-04-19 19:00:00  42.060689   27.331932   57.693637

# %%
from prophet.plot import plot_plotly

fig = plot_plotly(model, forcast)
fig.show()

fig2.savefig("Relative_Humidity_Forecast.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = model.plot_components(forcast)
fig2.savefig("RH_Forecast_Components.png")
